# %%
# we'd like the 'timestamp' column to be imported into pandas as a 'datetime' object
# but it's getting imported as an 'object'

# using pd.to_datetime() is slow and memory intensive
# we can do this in a chunked approach to avoid memory issues

# first check how many 'row groups' are in the parquet file
# if they are small enough, we can use a native pyarrow function to import the data
# if not, we can use a custom function to import the data in chunks
import pyarrow.parquet as pq


def check_row_groups(file_path):
    parquet_file = pq.ParquetFile(file_path)
    num_row_groups = parquet_file.num_row_groups
    print(f'Total Row Groups: {num_row_groups}')
    for i in range(num_row_groups):
        row_group = parquet_file.metadata.row_group(i)
        print(f'Row Group {i} Rows: {row_group.num_rows}')

# Check the row groups in your Parquet file
check_row_groups('../data/train_series.parquet')
# Out:
# Total Row Groups: 488
# Row Group 0 Rows: 262185
# Row Group 1 Rows: 262185
# Row Group 2 Rows: 262185
# Row Group 3 Rows: 262185
# Row Group 4 Rows: 262185
# Row Group 5 Rows: 262185
# Row Group 6 Rows: 262185
# Row Group 7 Rows: 262185
# Row Group 8 Rows: 262185
# Row Group 9 Rows: 262185
# Row Group 10 Rows: 262185
# Row Group 11 Rows: 262185
# Row Group 12 Rows: 262185
# Row Group 13 Rows: 262185
# Row Group 14 Rows: 262185
# Row Group 15 Rows: 262185
# Row Group 16 Rows: 262185
# Row Group 17 Rows: 262185
# Row Group 18 Rows: 262185
# Row Group 19 Rows: 262185
# Row Group 20 Rows: 262185
# Row Group 21 Rows: 262185
# Row Group 22 Rows: 262185
# Row Group 23 Rows: 262185
# Row Group 24 Rows: 262185
# Row Group 25 Rows: 262185
# Row Group 26 Rows: 262185
# Row Group 27 Rows: 262185
# Row Group 28 Rows: 262185
# Row Group 29 Rows: 262185
# Row Group 30 Rows: 262185
# Row Group 31 Rows: 262185
# Row Group 32 Rows: 262185
# Row Group 33 Rows: 262185
# Row Group 34 Rows: 262185
# Row Group 35 Rows: 262185
# Row Group 36 Rows: 262185
# Row Group 37 Rows: 262185
# Row Group 38 Rows: 262185
# Row Group 39 Rows: 262185
# Row Group 40 Rows: 262185
# Row Group 41 Rows: 262185
# Row Group 42 Rows: 262185
# Row Group 43 Rows: 262185
# Row Group 44 Rows: 262185
# Row Group 45 Rows: 262185
# Row Group 46 Rows: 262185
# Row Group 47 Rows: 262185
# Row Group 48 Rows: 262185
# Row Group 49 Rows: 262185
# Row Group 50 Rows: 262185
# Row Group 51 Rows: 262185
# Row Group 52 Rows: 262185
# Row Group 53 Rows: 262185
# Row Group 54 Rows: 262185
# Row Group 55 Rows: 262185
# Row Group 56 Rows: 262185
# Row Group 57 Rows: 262185
# Row Group 58 Rows: 262185
# Row Group 59 Rows: 262185
# Row Group 60 Rows: 262185
# Row Group 61 Rows: 262185
# Row Group 62 Rows: 262185
# Row Group 63 Rows: 262185
# Row Group 64 Rows: 262185
# Row Group 65 Rows: 262185
# Row Group 66 Rows: 262185
# Row Group 67 Rows: 262185
# Row Group 68 Rows: 262185
# Row Group 69 Rows: 262185
# Row Group 70 Rows: 262185
# Row Group 71 Rows: 262185
# Row Group 72 Rows: 262185
# Row Group 73 Rows: 262185
# Row Group 74 Rows: 262185
# Row Group 75 Rows: 262185
# Row Group 76 Rows: 262185
# Row Group 77 Rows: 262185
# Row Group 78 Rows: 262185
# Row Group 79 Rows: 262185
# Row Group 80 Rows: 262185
# Row Group 81 Rows: 262185
# Row Group 82 Rows: 262185
# Row Group 83 Rows: 262185
# Row Group 84 Rows: 262185
# Row Group 85 Rows: 262185
# Row Group 86 Rows: 262185
# Row Group 87 Rows: 262185
# Row Group 88 Rows: 262185
# Row Group 89 Rows: 262185
# Row Group 90 Rows: 262185
# Row Group 91 Rows: 262185
# Row Group 92 Rows: 262185
# Row Group 93 Rows: 262185
# Row Group 94 Rows: 262185
# Row Group 95 Rows: 262185
# Row Group 96 Rows: 262185
# Row Group 97 Rows: 262185
# Row Group 98 Rows: 262185
# Row Group 99 Rows: 262185
# Row Group 100 Rows: 262185
# Row Group 101 Rows: 262185
# Row Group 102 Rows: 262185
# Row Group 103 Rows: 262185
# Row Group 104 Rows: 262185
# Row Group 105 Rows: 262185
# Row Group 106 Rows: 262185
# Row Group 107 Rows: 262185
# Row Group 108 Rows: 262185
# Row Group 109 Rows: 262185
# Row Group 110 Rows: 262185
# Row Group 111 Rows: 262185
# Row Group 112 Rows: 262185
# Row Group 113 Rows: 262185
# Row Group 114 Rows: 262185
# Row Group 115 Rows: 262185
# Row Group 116 Rows: 262185
# Row Group 117 Rows: 262185
# Row Group 118 Rows: 262185
# Row Group 119 Rows: 262185
# Row Group 120 Rows: 262185
# Row Group 121 Rows: 262185
# Row Group 122 Rows: 262185
# Row Group 123 Rows: 262185
# Row Group 124 Rows: 262185
# Row Group 125 Rows: 262185
# Row Group 126 Rows: 262185
# Row Group 127 Rows: 262185
# Row Group 128 Rows: 262185
# Row Group 129 Rows: 262185
# Row Group 130 Rows: 262185
# Row Group 131 Rows: 262185
# Row Group 132 Rows: 262185
# Row Group 133 Rows: 262185
# Row Group 134 Rows: 262185
# Row Group 135 Rows: 262185
# Row Group 136 Rows: 262185
# Row Group 137 Rows: 262185
# Row Group 138 Rows: 262185
# Row Group 139 Rows: 262185
# Row Group 140 Rows: 262185
# Row Group 141 Rows: 262185
# Row Group 142 Rows: 262185
# Row Group 143 Rows: 262185
# Row Group 144 Rows: 262185
# Row Group 145 Rows: 262185
# Row Group 146 Rows: 262185
# Row Group 147 Rows: 262185
# Row Group 148 Rows: 262185
# Row Group 149 Rows: 262185
# Row Group 150 Rows: 262185
# Row Group 151 Rows: 262185
# Row Group 152 Rows: 262185
# Row Group 153 Rows: 262185
# Row Group 154 Rows: 262185
# Row Group 155 Rows: 262185
# Row Group 156 Rows: 262185
# Row Group 157 Rows: 262185
# Row Group 158 Rows: 262185
# Row Group 159 Rows: 262185
# Row Group 160 Rows: 262185
# Row Group 161 Rows: 262185
# Row Group 162 Rows: 262185
# Row Group 163 Rows: 262185
# Row Group 164 Rows: 262185
# Row Group 165 Rows: 262185
# Row Group 166 Rows: 262185
# Row Group 167 Rows: 262185
# Row Group 168 Rows: 262185
# Row Group 169 Rows: 262185
# Row Group 170 Rows: 262185
# Row Group 171 Rows: 262185
# Row Group 172 Rows: 262185
# Row Group 173 Rows: 262185
# Row Group 174 Rows: 262185
# Row Group 175 Rows: 262185
# Row Group 176 Rows: 262185
# Row Group 177 Rows: 262185
# Row Group 178 Rows: 262185
# Row Group 179 Rows: 262185
# Row Group 180 Rows: 262185
# Row Group 181 Rows: 262185
# Row Group 182 Rows: 262185
# Row Group 183 Rows: 262185
# Row Group 184 Rows: 262185
# Row Group 185 Rows: 262185
# Row Group 186 Rows: 262185
# Row Group 187 Rows: 262185
# Row Group 188 Rows: 262185
# Row Group 189 Rows: 262185
# Row Group 190 Rows: 262185
# Row Group 191 Rows: 262185
# Row Group 192 Rows: 262185
# Row Group 193 Rows: 262185
# Row Group 194 Rows: 262185
# Row Group 195 Rows: 262185
# Row Group 196 Rows: 262185
# Row Group 197 Rows: 262185
# Row Group 198 Rows: 262185
# Row Group 199 Rows: 262185
# Row Group 200 Rows: 262185
# Row Group 201 Rows: 262185
# Row Group 202 Rows: 262185
# Row Group 203 Rows: 262185
# Row Group 204 Rows: 262185
# Row Group 205 Rows: 262185
# Row Group 206 Rows: 262185
# Row Group 207 Rows: 262185
# Row Group 208 Rows: 262185
# Row Group 209 Rows: 262185
# Row Group 210 Rows: 262185
# Row Group 211 Rows: 262185
# Row Group 212 Rows: 262185
# Row Group 213 Rows: 262185
# Row Group 214 Rows: 262185
# Row Group 215 Rows: 262185
# Row Group 216 Rows: 262185
# Row Group 217 Rows: 262185
# Row Group 218 Rows: 262185
# Row Group 219 Rows: 262185
# Row Group 220 Rows: 262185
# Row Group 221 Rows: 262185
# Row Group 222 Rows: 262185
# Row Group 223 Rows: 262185
# Row Group 224 Rows: 262185
# Row Group 225 Rows: 262185
# Row Group 226 Rows: 262185
# Row Group 227 Rows: 262185
# Row Group 228 Rows: 262185
# Row Group 229 Rows: 262185
# Row Group 230 Rows: 262185
# Row Group 231 Rows: 262185
# Row Group 232 Rows: 262185
# Row Group 233 Rows: 262185
# Row Group 234 Rows: 262185
# Row Group 235 Rows: 262185
# Row Group 236 Rows: 262185
# Row Group 237 Rows: 262185
# Row Group 238 Rows: 262185
# Row Group 239 Rows: 262185
# Row Group 240 Rows: 262185
# Row Group 241 Rows: 262185
# Row Group 242 Rows: 262185
# Row Group 243 Rows: 262185
# Row Group 244 Rows: 262185
# Row Group 245 Rows: 262185
# Row Group 246 Rows: 262185
# Row Group 247 Rows: 262185
# Row Group 248 Rows: 262185
# Row Group 249 Rows: 262185
# Row Group 250 Rows: 262185
# Row Group 251 Rows: 262185
# Row Group 252 Rows: 262185
# Row Group 253 Rows: 262185
# Row Group 254 Rows: 262185
# Row Group 255 Rows: 262185
# Row Group 256 Rows: 262185
# Row Group 257 Rows: 262185
# Row Group 258 Rows: 262185
# Row Group 259 Rows: 262185
# Row Group 260 Rows: 262185
# Row Group 261 Rows: 262185
# Row Group 262 Rows: 262185
# Row Group 263 Rows: 262185
# Row Group 264 Rows: 262185
# Row Group 265 Rows: 262185
# Row Group 266 Rows: 262185
# Row Group 267 Rows: 262185
# Row Group 268 Rows: 262185
# Row Group 269 Rows: 262185
# Row Group 270 Rows: 262185
# Row Group 271 Rows: 262185
# Row Group 272 Rows: 262185
# Row Group 273 Rows: 262185
# Row Group 274 Rows: 262185
# Row Group 275 Rows: 262185
# Row Group 276 Rows: 262185
# Row Group 277 Rows: 262185
# Row Group 278 Rows: 262185
# Row Group 279 Rows: 262185
# Row Group 280 Rows: 262185
# Row Group 281 Rows: 262185
# Row Group 282 Rows: 262185
# Row Group 283 Rows: 262185
# Row Group 284 Rows: 262185
# Row Group 285 Rows: 262185
# Row Group 286 Rows: 262185
# Row Group 287 Rows: 262185
# Row Group 288 Rows: 262185
# Row Group 289 Rows: 262185
# Row Group 290 Rows: 262185
# Row Group 291 Rows: 262185
# Row Group 292 Rows: 262185
# Row Group 293 Rows: 262185
# Row Group 294 Rows: 262185
# Row Group 295 Rows: 262185
# Row Group 296 Rows: 262185
# Row Group 297 Rows: 262185
# Row Group 298 Rows: 262185
# Row Group 299 Rows: 262185
# Row Group 300 Rows: 262185
# Row Group 301 Rows: 262185
# Row Group 302 Rows: 262185
# Row Group 303 Rows: 262185
# Row Group 304 Rows: 262185
# Row Group 305 Rows: 262185
# Row Group 306 Rows: 262185
# Row Group 307 Rows: 262185
# Row Group 308 Rows: 262185
# Row Group 309 Rows: 262185
# Row Group 310 Rows: 262185
# Row Group 311 Rows: 262185
# Row Group 312 Rows: 262185
# Row Group 313 Rows: 262185
# Row Group 314 Rows: 262185
# Row Group 315 Rows: 262185
# Row Group 316 Rows: 262185
# Row Group 317 Rows: 262185
# Row Group 318 Rows: 262185
# Row Group 319 Rows: 262185
# Row Group 320 Rows: 262185
# Row Group 321 Rows: 262185
# Row Group 322 Rows: 262185
# Row Group 323 Rows: 262185
# Row Group 324 Rows: 262185
# Row Group 325 Rows: 262185
# Row Group 326 Rows: 262185
# Row Group 327 Rows: 262185
# Row Group 328 Rows: 262185
# Row Group 329 Rows: 262185
# Row Group 330 Rows: 262185
# Row Group 331 Rows: 262185
# Row Group 332 Rows: 262185
# Row Group 333 Rows: 262185
# Row Group 334 Rows: 262185
# Row Group 335 Rows: 262185
# Row Group 336 Rows: 262185
# Row Group 337 Rows: 262185
# Row Group 338 Rows: 262185
# Row Group 339 Rows: 262185
# Row Group 340 Rows: 262185
# Row Group 341 Rows: 262185
# Row Group 342 Rows: 262185
# Row Group 343 Rows: 262185
# Row Group 344 Rows: 262185
# Row Group 345 Rows: 262185
# Row Group 346 Rows: 262185
# Row Group 347 Rows: 262185
# Row Group 348 Rows: 262185
# Row Group 349 Rows: 262185
# Row Group 350 Rows: 262185
# Row Group 351 Rows: 262185
# Row Group 352 Rows: 262185
# Row Group 353 Rows: 262185
# Row Group 354 Rows: 262185
# Row Group 355 Rows: 262185
# Row Group 356 Rows: 262185
# Row Group 357 Rows: 262185
# Row Group 358 Rows: 262185
# Row Group 359 Rows: 262185
# Row Group 360 Rows: 262185
# Row Group 361 Rows: 262185
# Row Group 362 Rows: 262185
# Row Group 363 Rows: 262185
# Row Group 364 Rows: 262185
# Row Group 365 Rows: 262185
# Row Group 366 Rows: 262185
# Row Group 367 Rows: 262185
# Row Group 368 Rows: 262185
# Row Group 369 Rows: 262185
# Row Group 370 Rows: 262185
# Row Group 371 Rows: 262185
# Row Group 372 Rows: 262185
# Row Group 373 Rows: 262185
# Row Group 374 Rows: 262185
# Row Group 375 Rows: 262185
# Row Group 376 Rows: 262185
# Row Group 377 Rows: 262185
# Row Group 378 Rows: 262185
# Row Group 379 Rows: 262185
# Row Group 380 Rows: 262185
# Row Group 381 Rows: 262185
# Row Group 382 Rows: 262185
# Row Group 383 Rows: 262185
# Row Group 384 Rows: 262185
# Row Group 385 Rows: 262185
# Row Group 386 Rows: 262185
# Row Group 387 Rows: 262185
# Row Group 388 Rows: 262185
# Row Group 389 Rows: 262185
# Row Group 390 Rows: 262185
# Row Group 391 Rows: 262185
# Row Group 392 Rows: 262185
# Row Group 393 Rows: 262185
# Row Group 394 Rows: 262185
# Row Group 395 Rows: 262185
# Row Group 396 Rows: 262185
# Row Group 397 Rows: 262185
# Row Group 398 Rows: 262185
# Row Group 399 Rows: 262185
# Row Group 400 Rows: 262185
# Row Group 401 Rows: 262185
# Row Group 402 Rows: 262185
# Row Group 403 Rows: 262185
# Row Group 404 Rows: 262185
# Row Group 405 Rows: 262185
# Row Group 406 Rows: 262185
# Row Group 407 Rows: 262185
# Row Group 408 Rows: 262185
# Row Group 409 Rows: 262185
# Row Group 410 Rows: 262185
# Row Group 411 Rows: 262185
# Row Group 412 Rows: 262185
# Row Group 413 Rows: 262185
# Row Group 414 Rows: 262185
# Row Group 415 Rows: 262185
# Row Group 416 Rows: 262185
# Row Group 417 Rows: 262185
# Row Group 418 Rows: 262185
# Row Group 419 Rows: 262185
# Row Group 420 Rows: 262185
# Row Group 421 Rows: 262185
# Row Group 422 Rows: 262185
# Row Group 423 Rows: 262185
# Row Group 424 Rows: 262185
# Row Group 425 Rows: 262185
# Row Group 426 Rows: 262185
# Row Group 427 Rows: 262185
# Row Group 428 Rows: 262185
# Row Group 429 Rows: 262185
# Row Group 430 Rows: 262185
# Row Group 431 Rows: 262185
# Row Group 432 Rows: 262185
# Row Group 433 Rows: 262185
# Row Group 434 Rows: 262185
# Row Group 435 Rows: 262185
# Row Group 436 Rows: 262185
# Row Group 437 Rows: 262185
# Row Group 438 Rows: 262185
# Row Group 439 Rows: 262185
# Row Group 440 Rows: 262185
# Row Group 441 Rows: 262185
# Row Group 442 Rows: 262185
# Row Group 443 Rows: 262185
# Row Group 444 Rows: 262185
# Row Group 445 Rows: 262185
# Row Group 446 Rows: 262185
# Row Group 447 Rows: 262185
# Row Group 448 Rows: 262185
# Row Group 449 Rows: 262185
# Row Group 450 Rows: 262185
# Row Group 451 Rows: 262185
# Row Group 452 Rows: 262185
# Row Group 453 Rows: 262185
# Row Group 454 Rows: 262185
# Row Group 455 Rows: 262185
# Row Group 456 Rows: 262185
# Row Group 457 Rows: 262185
# Row Group 458 Rows: 262185
# Row Group 459 Rows: 262185
# Row Group 460 Rows: 262185
# Row Group 461 Rows: 262185
# Row Group 462 Rows: 262185
# Row Group 463 Rows: 262185
# Row Group 464 Rows: 262185
# Row Group 465 Rows: 262185
# Row Group 466 Rows: 262185
# Row Group 467 Rows: 262185
# Row Group 468 Rows: 262185
# Row Group 469 Rows: 262185
# Row Group 470 Rows: 262185
# Row Group 471 Rows: 262185
# Row Group 472 Rows: 262185
# Row Group 473 Rows: 262185
# Row Group 474 Rows: 262185
# Row Group 475 Rows: 262185
# Row Group 476 Rows: 262185
# Row Group 477 Rows: 262185
# Row Group 478 Rows: 262185
# Row Group 479 Rows: 262185
# Row Group 480 Rows: 262185
# Row Group 481 Rows: 262185
# Row Group 482 Rows: 262185
# Row Group 483 Rows: 262185
# Row Group 484 Rows: 262185
# Row Group 485 Rows: 262185
# Row Group 486 Rows: 262185
# Row Group 487 Rows: 262245

# %%
import os
import fastparquet as fp
import pandas as pd

# there are 488 symmetrical row groups in the train_series.parquet file
# so we can use the native pyarrow function to import the data
def process_and_save_in_chunks(input_file_path, output_file_path):
    parquet_file = pq.ParquetFile(input_file_path)
    num_row_groups = parquet_file.num_row_groups

    temp_files = []  # List to hold temporary file paths

    # Process each row group
    for i in range(num_row_groups):
        table = parquet_file.read_row_group(i)
        df = table.to_pandas()

        # Convert to datetime and handle errors
        df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%dT%H:%M:%S%z', errors='coerce', utc=True)

        # Check for NaT values
        nat_rows = df[df['timestamp'].isna()]
        if not nat_rows.empty:
            print(f"NaT values found in chunk {i}:")
            print(nat_rows)

        # Convert to UTC and remove timezone information if dtype is correct
        if isinstance(df['timestamp'].dtype, pd.DatetimeTZDtype):
            df['timestamp'] = df['timestamp'].dt.tz_convert('UTC').dt.tz_localize(None)
        else:
            print(f"Skipped timezone conversion for chunk {i} due to incorrect dtype.")
        
        # Check for an empty DataFrame and exit early if found
        if df.empty:
            print(f"Empty DataFrame detected in chunk {i}. Exiting.")
            return
        
        # Write the chunk to a temporary Parquet file
        temp_file_path = f'temp_file_{i}.parquet'
        temp_files.append(temp_file_path)
        df.to_parquet(temp_file_path, index=False)

    # Combine the temporary Parquet files into a single Parquet dataset
    # list_of_dfs = [pd.read_parquet(temp_file) for temp_file in temp_files]
    # final_df = pd.concat(list_of_dfs, axis=0)
    # final_df.to_parquet(output_file_path, index=False)

    # fp.writer.merge(temp_files, output_file_path)
    
    import pyarrow.parquet as pq
    import shutil
    
    # Initialize with the first file
    shutil.copy(temp_files[0], output_file_path)
    # Open the output file in append mode
    output_file = pq.ParquetWriter(
        output_file_path,
        schema=pq.ParquetFile(temp_files[0]).schema
        )
    # Append data from subsequent temporary files
    for temp_file in temp_files[1:]:
        table = pq.read_table(temp_file)
        output_file.write_table(table)

    # Close the output file
    output_file.close()
    
    # check the output
    merged_df = pd.read_parquet(output_file_path)
    print(merged_df)

    # remove the temporary Parquet files
    for temp_file_path in temp_files:
        os.remove(temp_file_path)


# Call the function
file_bases = ['train_series']

for base in file_bases:
    input_file = f'../data/{base}.parquet'
    output_file = f'../data/{base}_datecorrected.parquet'
    process_and_save_in_chunks(input_file, output_file)

# %%
import os
import pyarrow.parquet as pq

files = []
input_folder = r"../notebooks"
target_path = r"../data/train_series_datecorrected.parquet"

for file_name in os.listdir(input_folder):
    if os.path.splitext(file_name)[1] == ".parquet":
        files.append(pq.read_table(os.path.join(input_folder, file_name)))

with pq.ParquetWriter(target_path, files[0].schema, version='2.0', compression='gzip', use_dictionary=True, data_page_size=2097152) as writer:
    for f in files:
        writer.write_table(f)
# Out:
# C:\Users\dekel\AppData\Local\Temp\ipykernel_7324\3446540102.py:12: FutureWarning: Parquet format '2.0' pseudo version is deprecated, use '2.4' or '2.6' for fine-grained feature selection
#   with pq.ParquetWriter(target_path, files[0].schema, version='2.0', compression='gzip', use_dictionary=True, data_page_size=2097152) as writer:

# %%
# check that the files are the same
import pandas as pd

def compare_parquet_files(file1: str, file2: str) -> bool:
    """
    Compare two Parquet files to determine if they are identical.
    
    Parameters:
    - file1: Path to the first Parquet file.
    - file2: Path to the second Parquet file.
    """
    
    # Read the Parquet files into DataFrames
    df1 = pd.read_parquet(file1)
    df2 = pd.read_parquet(file2)

    # Check row differences
    if df1.shape[0] != df2.shape[0]:
        print(f"Row count difference: File1 has {df1.shape[0]} rows, while File2 has {df2.shape[0]} rows.")
        
    # Check column differences
    diff_columns = set(df1.columns) ^ set(df2.columns)
    if diff_columns:
        print(f"Different columns found: {', '.join(diff_columns)}")

    # Check for row data differences and display a sample
    if not df1.equals(df2):
        differing_rows = (df1 != df2).any(axis=1)
        sample_differing_rows = df1[differing_rows].head()  # Adjust this to display more rows if needed
        sample_differing_rows2 = df2[differing_rows].head()  # Adjust this to display more rows if needed
        print("Sample rows that differ between files:")
        print(sample_differing_rows)
        print("Versus:")
        print(sample_differing_rows2)

# Example usage:
file_path_original = '../data/train_series.parquet'
file_path_processed = '../data/train_series_datecorrected.parquet'

compare_parquet_files(file_path_original, file_path_processed)
# Out:
# C:\Users\dekel\AppData\Local\Temp\ipykernel_26052\3061430774.py:28: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise a warning unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   differing_rows = (df1 != df2).any(axis=1)
# Sample rows that differ between files:
#       series_id  step                 timestamp  anglez    enmo
# 0  038441c925bb     0  2018-08-14T15:30:00-0400  2.6367  0.0217
# 1  038441c925bb     1  2018-08-14T15:30:05-0400  2.6368  0.0215
# 2  038441c925bb     2  2018-08-14T15:30:10-0400  2.6370  0.0216
# 3  038441c925bb     3  2018-08-14T15:30:15-0400  2.6368  0.0213
# 4  038441c925bb     4  2018-08-14T15:30:20-0400  2.6368  0.0215
# Versus:
#       series_id  step           timestamp  anglez    enmo
# 0  038441c925bb     0 2018-08-14 19:30:00  2.6367  0.0217
# 1  038441c925bb     1 2018-08-14 19:30:05  2.6368  0.0215
# 2  038441c925bb     2 2018-08-14 19:30:10  2.6370  0.0216
# 3  038441c925bb     3 2018-08-14 19:30:15  2.6368  0.0213
# 4  038441c925bb     4 2018-08-14 19:30:20  2.6368  0.0215
